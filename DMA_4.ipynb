# %% [markdown]
# <a href="https://colab.research.google.com/github/ANANAYAGG/AI_LAB/blob/main/DMA_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('/content/comfy-ui.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello, World

# %%
content = "Hello, World"


with open('/content/comfy-ui.txt', 'w') as file:
    file.write(content)

# %%
import pandas as pd
df=pd.read_csv("/content/punjab-macro-soil.csv")

# %%
df.head()
# Out:
#     State Copper - Sufficient  Copper - Deficient  Boron - Sufficient  \
# 0  PUNJAB                100%                  0%                 50%
# 1  PUNJAB                100%                  0%                  0%
# 2  PUNJAB                  0%                  0%                  0%
# 3  PUNJAB                100%                  0%                  0%
# 4  PUNJAB  88.88888888888889%  11.11111111111111%  65.65656565656566%
#
#      Boron - Deficient      S - Sufficient        S - Deficient  \
# 0                  50%  76.34408602150538%  23.655913978494624%
# 1                   0%                  0%                   0%
# 2                   0%                  0%                   0%
# 3                   0%                  0%                   0%
# 4  34.343434343434346%                 51%                  49%
#
#      Fe - Sufficient      Fe - Deficient     Zn - Sufficient  \
# 0  95.6989247311828%  4.301075268817204%  97.84946236559139%
# ...

# %%
import urllib3

http = urllib3.PoolManager()

response = http.request('GET', 'https://www.kaggle.com/competitions/System-Threat-Forecaster/overview')

if response.status == 200:

    html_content = response.data.decode('utf-8')
    print(html_content)
else:
    print(f"Request failed with status code: {response.status}")


response.release_conn()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <title>Kaggle: Your Home for Data Science</title>
#   <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#   <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#   <meta name="theme-color" content="#008ABC" />
#   <script nonce="PK5FjeK1g9mtsg30Zb3KJQ==" type="text/javascript">
#     window["pageRequestStartTime"] = 1739858605500;
#     window["pageRequestEndTime"] = 1739858605503;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
#   <script nonce="PK5FjeK1g9mtsg30Zb3KJQ==" id="gsi-client" src="https://accounts.google.com/gsi/client" async defer></script>
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from PyPDF2 import PdfReader

def read_pdf(path):
    with open(path, 'rb') as file:
        pdf_reader = PdfReader(file)
        num_pages = len(pdf_reader.pages)

        for page_num in range(num_pages):
            page = pdf_reader.pages[page_num]
            text = page.extract_text()
            print(f"Page {page_num + 1}:")
            print(text)


pdf_path = '/content/dma_ananay_p2.pdf'
read_pdf(pdf_path)
# Out:
# Page 1:
# UNIVERSITY INSTITUTE OF
# ENGINEERING AND TECHNOLOGY
# (UIET)
# PANJAB UNIVERSITY, CHANDIGARH
#
#
#
#
#
#
#
#
# DATA MINING AND ANALYSIS (P)
#
# COMPUTER SCIENCE AND ENGINEERING(CSE)
# 6TH SEMESTER(2022 -2026)
#
#
#
# Submitted by - Ananay Aggarwal
# Roll no -UE2230 11 Group -1,Section -1
# Submitted To - Dr. Sarbjeet Singh
#
#
#
# Page 2:
#
# Practical: - Overview of Python Decision Making,
# Loops, Strings
#
#
# Python Decision Making
# Decision -making structures allow the execution of specific
# code blocks based on conditions. Python uses:
# • if statements: Execute a block of code when a condition
# evaluates to True.
# • if-else statements: Provide an alternative block if the
# condition is False.
# • if-elif-else statements: Test multiple conditions
# sequentially until one condition is met.
# These structures help control program flow and logic.
#
# Loops in Python
# Loops enable repetitive execution of code until a certain
# condition is met:
# ...
